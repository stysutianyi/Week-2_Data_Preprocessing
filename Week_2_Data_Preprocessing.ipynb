# %% [markdown]
# <a href="https://colab.research.google.com/github/IAT-ExploringAI-2024/Week-2_Data_Preprocessing/blob/main/Week_2_Data_Preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# from google.colab import drive

# drive.mount("/content/drive")

# %% [markdown]
# In this notebook, we'll explore of Artificial Intelligence Workflow, putting a spotlight on the crucial step of Data Preprocessing.
#
# To make things clear, we'll showcase different types of data. This will help you recognize how various datasets look, where you can find them, and the steps to bring them into your work.
#
# We'll also explore specific libraries tailored for each type of data. This way, you'll get hands-on experience with the tools designed to handle different data formats effectively.
#
# After that, it's time to get hands-on with these datasets. We'll take a closer look at their unique features, understand whether they present classification or regression challenges, and use visualization techniques to make sense of the data's patterns. This practical approach not only hones your skills in data preprocessing but also empowers you to smoothly integrate various libraries and techniques into your AI workflow.

# %% [markdown]
# # **Artificial Intelligence Workflow**

# %% [markdown]
# ![ml-engineering.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **Three Main Steps**:
#
# 1.  Data Preprocessing
# 2.  Model Engineering
# 3.  Model Depolyment
#
# **DATA Preprocessing**
#
# - Data Gathering/Integration
# - Data Exploration
# - Data Cleaning
# - Data Transforming
#
# **Model Engineering**
#
# - Model Training
# - Model Evaluation
# - Model Testing
#
# **Model Deployment**
#
# - Model Serving
# - Model Performance monitoring

# %% [markdown]
# # **Important Libraries**

# %% [markdown]
# **Libraries required for importing data**:
#
# - Pandas
#
# **Libraries required for visualizing data**:
#
# - Matplotlib
# - seaborn
#
# **Libraries required for handling specific data types:**
#
# - Numerical => Numpy
# - Images => OpenCV
# - Text => NLTK
# - Audio => Librosa

# %%
import pandas

# %% [markdown]
# You cannot import libraries before installing them!

# %% [markdown]
# ## **Installing Libraries**
#
# If you are using Google Colab, some of the libraries are preinstalled .
#
# If you are using Anaconda, almost all the libraries will be pre installed with the package.
#
# If you have downloaded individual Jupyter notebook you will need to install all the required libraries before importing them into code.
#
# Must ensure that you have pip installed in your systems

# %%
# !python3 -m pip --version
# Out:
# pip 22.2.2 from /Users/tigersu/opt/anaconda3/lib/python3.9/site-packages/pip (python 3.9)

# %% [markdown]
# Install the library in Python using the pip command in the command prompt (cmd)
#
# You can also install libraries directly from the jupyter notebook by placing "!" before any command.
#
# ```
# !pip install package_name
# ```
#
# For the purpose of this notebook, we need to install all the above mentioned libararies, make sure to install them if they are not already installed.

# %%
# !pip install pandas
# !pip install matplotlib
# !pip install seaborn
# !pip install numpy
# !pip install opencv-python
# !pip install nltk
# !pip install librosa

# %% [markdown]
# Importing Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import cv2
import nltk
import librosa

# %% [markdown]
# # **DIFFERENT TYPES OF DATA**
#
# - **Tabular Data**
#
#   - Categorical Labels
#
#   - Numerical Labels
#
# - **Textual Data**
#
# - **Images Data**
#
# - **Audio Data**

# %% [markdown]
# For Today's tutorial we will be looking into:
#
# - Tabular data (brief overview and pre processing)
# - Audio Data (detailed overview and pre processing)

# %% [markdown]
# ## **Tabular Data**
#
# - Categorical Labels
# - Numerical Labels

# %% [markdown]
# ### **Iris Dataset (Categorical Labels)**

# %% [markdown]
# The Iris flower data set consists of 150 samples.
#
# **Three species of Iris:**
#
# - Iris setosa
# - Iris virginica
# - Iris versicolor
#
# **Four features were measured for each sample:**
#
# - Length of the sepals (cm)
# - Width of the sepals (cm)
# - Length of the petals (cm)
# - Width of the petals (cm)
#
# **Problem Statement:**
#
# Distinguish the flowers based on these features.
#
# _Independent variables (Features)_:
#
# - Length of the sepals
# - Length of the petals
# - Width of the sepals
# - Width of the petals
#
# _Dependent variables (Labels)_:
#
# - Species of the flower

# %% [markdown]
# **Importing Required libraries**

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# **Loading Dataset**
#
# Download the dataset from : https://www.kaggle.com/datasets/uciml/iris
#
# Copy the path of the dataset and paste it in the command _below_

# %%
dataset_1 = pd.read_csv("Iris.csv")

# %% [markdown]
# Preview the dataset

# %%
dataset_1.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
dataset_1.shape
# Out:
# (150, 6)

# %%
dataset_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %% [markdown]
# When the data is simply analyzed, none of the 6 columns contain null values, which will be a great advantage. The "Species" column will be the target feature and except for the "Id" column, which can be ignored, the other columns are of type "float64".

# %%
dataset_1.describe(include="all")
# Out:
#                 Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# count   150.000000     150.000000    150.000000     150.000000    150.000000
# unique         NaN            NaN           NaN            NaN           NaN
# top            NaN            NaN           NaN            NaN           NaN
# freq           NaN            NaN           NaN            NaN           NaN
# mean     75.500000       5.843333      3.054000       3.758667      1.198667
# std      43.445368       0.828066      0.433594       1.764420      0.763161
# min       1.000000       4.300000      2.000000       1.000000      0.100000
# 25%      38.250000       5.100000      2.800000       1.600000      0.300000
# 50%      75.500000       5.800000      3.000000       4.350000      1.300000
# 75%     112.750000       6.400000      3.300000       5.100000      1.800000
# max     150.000000       7.900000      4.400000       6.900000      2.500000
#
#             Species
# count           150
# unique            3
# top     Iris-setosa
# freq             50
# mean            NaN
# std             NaN
# min             NaN
# 25%             NaN
# 50%             NaN
# 75%             NaN
# max             NaN

# %% [markdown]
# In the describe method, apart from the parameters that are very useful for numerical features (mean, median, 1Q, 3Q etc.), parameters such as "unique, top, freq" that will be used for categorical features are indicated with "include=all".

# %%
dataset_1["Species"].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64

# %% [markdown]
# The 3 different variables of the target feature are distributed in equal numbers.

# %%
# fig, (ax1, ax2) = plt.subplots(2, 2)
# sns.barplot(dataset_1, x=dataset_1.Species, y=dataset_1.SepalLengthCm, ax=ax1[0])
# sns.barplot(dataset_1, x=dataset_1.Species, y=dataset_1.SepalWidthCm, ax=ax1[1])
# sns.barplot(dataset_1, x=dataset_1.Species, y=dataset_1.PetalWidthCm, ax=ax2[0])
# sns.barplot(dataset_1, x=dataset_1.Species, y=dataset_1.PetalLengthCm, ax=ax2[1])
# plt.tight_layout()
# plt.show()

fig, (ax1, ax2) = plt.subplots(2, 2)
sns.barplot(data=dataset_1, x="Species", y="SepalLengthCm", ax=ax1[0])
sns.barplot(data=dataset_1, x="Species", y="SepalWidthCm", ax=ax1[1])
sns.barplot(data=dataset_1, x="Species", y="PetalWidthCm", ax=ax2[0])
sns.barplot(data=dataset_1, x="Species", y="PetalLengthCm", ax=ax2[1])
plt.tight_layout()
plt.show()

# %%
sns.FacetGrid(dataset_1, hue="Species").map(
    plt.scatter, "SepalLengthCm", "SepalWidthCm"
).add_legend()

# %% [markdown]
# Explore the dataset more from : https://www.kaggle.com/datasets/uciml/iris

# %% [markdown]
# ### **House Price Prediction (Numerical Labels)**

# %% [markdown]
# Consisting of 4600 entries for homes in different US cities, this dataset includes 18 different variables that describe various property details such as size and location characteristics.
#
# **Columns**
#
# - date: Date the house was sold
# - price: Sale price of the house (Prediction target)
# - bedrooms: Number of the bedrooms
# - bathrooms: Number the bathrooms
# - sqft_living: Square footage of the home
# - sqft_lot: Square footage of the lot
# - floors: Total floors (levels) in the house
# - waterfront: House which has a view to a waterfront
# - view: Number of views
# - condition: How good the condition is overall
# - sqft_above: Square footage of the house apart from basement
# - sqft_basement: Square footage of the basement
# - yr_built: Building year of the house
# - yr_renovated: Renovation year of the house
# - street: Street where the house is located
# - city: City where the house is located
# - statezip: Zip code of the region where the house is located
# - country: Country where the house is located (USA)
#
# There are 8 categorical (half nominal and half ordinal depending on the measurement level) and 9 discrete variables.
#
# Our ordinal variables, waterfront, view and and renovation year, appear numerically, but we will evaluate them in two categories, 0 and 1, depending on whether they are in the relevant house or not. Also, the condition has 5 unique values that increase from 1 to 5 based on the state of the house. And as you might guess, street, city, statezip, and country are the nominal ones.
#
# **Types of Data**
#
# - Categorical (gender, blood type, aswers of yes/no questions, satisfaction/condition level etc.)
#
# - Numerical
#   1.  Discrete (finite numbers- # of children/customer/room,physical money, time on a clock etc.)
#   2.  Continuous (infinite numbers- measurements(weight, height), time in general etc.)
#
# **Levels of Measurement**
#
# - Qualitative
#   a. Nominal (Can not be ordered- gender, blood type, seasons)
#   b. Ordinal (Takes values with an order or rank- satisfaction, condition level)
# - Quantitative
#   a. Interval (Don't have a true zero- temperature, pH, IQ test etc.)
#   b. Ratios (Have a true zero- temperature only in Kelvin, amount, distance, pulse etc.)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# **Loading Dataset**
#
# Download the dataset from :https://www.kaggle.com/datasets/shree1992/housedata/data
# Copy the path of the dataset and paste it in the command _below_

# %%
dataset_2 = pd.read_csv("HousePricePrediction.csv")

# %% [markdown]
# **Exploring Dataset**

# %%
dataset_2.head()
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-02 00:00:00   313000.0       3.0       1.50         1340      7912
# 1  2014-05-02 00:00:00  2384000.0       5.0       2.50         3650      9050
# 2  2014-05-02 00:00:00   342000.0       3.0       2.00         1930     11947
# 3  2014-05-02 00:00:00   420000.0       3.0       2.25         2000      8030
# 4  2014-05-02 00:00:00   550000.0       4.0       2.50         1940     10500
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5           0     0          3        1340              0      1955
# 1     2.0           0     4          5        3370            280      1921
# 2     1.0           0     0          4        1930              0      1966
# 3     1.0           0     0          4        1000           1000      1963
# 4     1.0           0     0          4        1140            800      1976
#
#    yr_renovated                    street       city  statezip country
# 0          2005      18810 Densmore Ave N  Shoreline  WA 98133     USA
# 1             0           709 W Blaine St    Seattle  WA 98119     USA
# 2             0  26206-26214 143rd Ave SE       Kent  WA 98042     USA
# 3             0           857 170th Pl NE   Bellevue  WA 98008     USA
# 4          1992         9105 170th Ave NE    Redmond  WA 98052     USA

# %%
dataset_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4600 entries, 0 to 4599
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           4600 non-null   object
#  1   price          4600 non-null   float64
#  2   bedrooms       4600 non-null   float64
#  3   bathrooms      4600 non-null   float64
#  4   sqft_living    4600 non-null   int64
#  5   sqft_lot       4600 non-null   int64
#  6   floors         4600 non-null   float64
#  7   waterfront     4600 non-null   int64
#  8   view           4600 non-null   int64
#  9   condition      4600 non-null   int64
#  10  sqft_above     4600 non-null   int64
#  11  sqft_basement  4600 non-null   int64
#  12  yr_built       4600 non-null   int64
#  13  yr_renovated   4600 non-null   int64
#  14  street         4600 non-null   object
#  15  city           4600 non-null   object
#  16  statezip       4600 non-null   object
#  17  country        4600 non-null   object
# dtypes: float64(4), int64(9), object(5)
# memory usage: 647.0+ KB

# %% [markdown]
# **Handling missing values**
#
# There is no NaN value in our data set, but it would be good to check 0's or 999's for the sake of data consistency. I don't see any irrelevant max values in the describe output but there are some zeros to check.

# %%
dataset_2[dataset_2 == 0].count()
# Out:
# date                0
# price              49
# bedrooms            2
# bathrooms           2
# sqft_living         0
# sqft_lot            0
# floors              0
# waterfront       4567
# view             4140
# condition           0
# sqft_above          0
# sqft_basement    2745
# yr_built            0
# yr_renovated     2735
# street              0
# city                0
# statezip            0
# country             0
# dtype: int64

# %% [markdown]
# We have to deal with 49 houses that look free of cost, plus 2 houses each without a bedroom and a bathroom. Since they are few in number, we can remove these values directly from our data set.

# %%
dataset_2 = dataset_2.drop(dataset_2[(dataset_2["price"] == 0)].index)
dataset_2 = dataset_2.drop(dataset_2[(dataset_2["bedrooms"] == 0)].index)
dataset_2 = dataset_2.drop(dataset_2[(dataset_2["bathrooms"] == 0)].index)

# %%
dataset_2.shape
# Out:
# (4549, 18)

# %% [markdown]
# We can see now 4549 samples are left after removing samples with missing data. We can further explore the data and find outliers.

# %%
# checking the target variables for distribution
sns.histplot(dataset_2["price"])
plt.title("Price")
# Out:
# Text(0.5, 1.0, 'Price')

# %% [markdown]
# You have to remove the outliers before proceeding with the modelling. Please explore [this ](https://www.analyticsvidhya.com/blog/2021/05/feature-engineering-how-to-detect-and-remove-outliers-with-python-code/) article for outlier detection and removal.

# %% [markdown]
# For further exploration see: https://www.kaggle.com/datasets/shree1992/housedata

# %% [markdown]
# ## **Audio Data**

# %% [markdown]
# <center><h1> Introduction to Audio Data Analysis </h1></center>
#
# As a first step towards Speech Emotion Recognition, this notebook serves as an introduction to data cleaning and feature engineering techniques for audio data.In the next notebooks, we will delve into various Machine learning algorithms to develop models to perform classification.
#
# Data cleansing and feature engineering comprise the most crucial aspect of preparing machine and deep learning models alike and is often the difference between success and failure. We can drastically improve the performance of a model with proper attention paid to feature engineering.
# For features to be useful in classification they must encompass sufficient variance between different classes.

# %% [markdown]
# **Introduction to RAVDESS dataset**
#
# We are going to use the RAVDESS dataset (Ryerson Audio-Visual Database of Emotional Speech and Song dataset), created by Steven Livingstone and Frank Russo of Ryerson University. <br>
# **Files**
# This portion of the RAVDESS contains 1440 files: 60 trials per actor x 24 actors = 1440. The RAVDESS contains 24 professional actors (12 female, 12 male), vocalizing two lexically-matched statements in a neutral North American accent. Speech emotions includes calm, happy, sad, angry, fearful, surprise, and disgust expressions. Each expression is produced at two levels of emotional intensity (normal, strong), with an additional neutral expression.
#
# **File naming convention**
#
# Each of the 1440 files has a unique filename. The filename consists of a 7-part numerical identifier (e.g., 03-01-06-01-02-01-12.wav). These identifiers define the stimulus characteristics:
#
# **Filename identifiers**
#
# - Modality (01 = full-AV, 02 = video-only, 03 = audio-only).
#
# - Vocal channel (01 = speech, 02 = song).
#
# - Emotion (01 = neutral, 02 = calm, 03 = happy, 04 = sad, 05 = angry, 06 = fearful, 07 = disgust, 08 = surprised).
#
# - Emotional intensity (01 = normal, 02 = strong). NOTE: There is no strong intensity for the 'neutral' emotion.
#
# - Statement (01 = "Kids are talking by the door", 02 = "Dogs are sitting by the door").
#
# - Repetition (01 = 1st repetition, 02 = 2nd repetition).
#
# - Actor (01 to 24. Odd numbered actors are male, even numbered actors are female).
#
# Filename example: 03-01-06-01-02-01-12.wav
#
# 1. Audio-only (03)
# 2. Speech (01)
# 3. Fearful (06)
# 4. Normal intensity (01)
# 5. Statement "dogs" (02)
# 6. 1st Repetition (01)
# 7. 12th Actor (12) Female, as the actor ID number is even.
#
# [Details of the RAVDESS dataset](https://psychlabs.torontomu.ca/smartlab/resources/speech-song-database-ravdess/) <br>
#
# The above link has some problems with the dataset,so i cleaned it a bit and you can access it and download it from [this link](https://drive.google.com/drive/folders/1OxhaA7DuOc7UYJZIajFlgshvdWDTLBqy?usp=sharing)
#
# We're going to use the audio-only speech portion of the RAVDESS dataset, ~200MB.
# Audio is sourced from 24 actors (12 male, 12 female) repeating two sentences with
# a variety of emotions and intensity. We get 1440 speech files (24 actors \* 60 recordings per actor). Each audio sample has been rated by a human 10 times for emotional quality.
#
# ### Machine Learning Process Overview
#
# 1. Feature Engineering: Choose and define the properties which our model will use to evaluate the audio files. <br>
# 2. Feature Extraction: Compute the features for each audio file and build a feature matrix representing all audio files. <br>
# 3. Model exploration: Test candidate models that make sense for the properies of the dataset
# 4. Training the MLP Classifier model: Choose and optimize the properties of our model on validation data - hyperparameters and architechture. <br>
# 5. Evaluate our model's performance: Evaluate our model's accuracy on validation data and score it against test data which it has never seen in training.<br>
# 6. Explore options for improving our model: Is our dataset the right size? Is our model too complex or too simple? <br>

# %% [markdown]
# _In this notebook, we are going to focus on first two steps of the process._
#
# 1. _Feature Engineering_
# 2. _Feature Extraction_

# %% [markdown]
# ### Feature Engineering
#
# Before building any sort of predictive models, we not only need data - but we need a usable representation. Enter feature engineering.
#
# An audio file can be represented as a time series with the dependent axis being
# the amplitude of the audio waveform. The waveform of the sound file is all the information we have with which to create features to train our model. However, the shape of a waveform does not carry enough discriminating information, so we need to transform the waveform into a more useable form. <br>
# Sometimes our input dataset _does_ have enough information to train a model to give accurate results - but even then input data should be scrutinized and transformed - this allows us to pick the best model for our features, which is usually much better and different than a model that works on our raw input data. Proper feature engineering carries advantages not limited to
#
# - **More accurate, generalizable models**
# - **Insight into model's decision-making behaviour**
# - **Flexibility in choice of models**
# - **Faster training**
#
# **Before feature engineering, we always cleanse our data** - which may consist of removing outliers (carefully), removing irrelevant input data according to business logic, or removing noise. For audio, data cleaning may consistent of making audio samples equal in length and padded with silence at either end. The RAVDESS dataset has done that for us, but this is a rare case.
#
# That being said, let's see what we're starting with by comparing the waveforms of "Happy" and "Angry" of Actor 1:

# %%
# Get the critical imports out of the way
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import librosa.display
import soundfile
import os

# matplotlib complains about the behaviour of librosa.display, so we'll ignore those warnings:
import warnings

warnings.filterwarnings("ignore")
from IPython.core.display import HTML

# Center matplotlib figures...
HTML(
    """
<style>
.output_png {
    display: table-cell;
    text-align: center;
    vertical-align: middle;
}
</style>
"""
)
# Out:
# <style>
# .output_png {
#     display: table-cell;
#     text-align: center;
#     vertical-align: middle;
# }
# </style>

# %%
################# Load Happy and Angry example of Actor 1 #####################################
with soundfile.SoundFile("RAVDESS/Actor_01/03-01-03-01-01-01-01.wav") as audio:
    waveform = audio.read(dtype="float32")
    sample_rate = audio.samplerate
    plt.figure(figsize=(15, 4))
    plt.subplot(1, 2, 1)
    librosa.display.waveshow(waveform, sr=sample_rate)
    plt.title("Happy")

with soundfile.SoundFile("RAVDESS/Actor_01/03-01-05-01-01-01-01.wav") as audio:
    waveform = audio.read(dtype="float32")
    sample_rate = audio.samplerate
    plt.subplot(1, 2, 2)
    librosa.display.waveshow(waveform, sr=sample_rate)
    plt.title("Angry")

# %% [markdown]
# Alright, there's a visible difference - but not enough to classify by emotion. Take my word for it. Try it if you like. However, raw waveforms can be used for certain other audio classification tasks with the right network.

# %% [markdown]
# So, where do we get features suitable for emotion classification?
#
# ### Short-Time Fourier Transform
#
# The lowest-hanging fruit in time series signal processing is, of course, the Fourier Transform.
# Specifically, we'll use the Short-Time Fourier Transform (STFT) which will cut our audio waveform into short, overlapping equal length segments and
# take the Fourier transform of each segment individually to produce multiple power spectrograms, identifying resonant frequencies present in our audio file. The major advantage of STFT is better resolution of _changes_ in the audio signal w.r.t. time. <br>
#
# If you want to explore Fourier transform please look into [this article.](https://medium.com/@ongzhixuan/exploring-the-short-time-fourier-transform-analyzing-time-varying-audio-signals-98157d1b9a12)

# %% [markdown]
# Let's start visualizing our features to get a better handle on them.
# Load a sample audio file from our dataset - each audio file is 3 seconds in length.

# %%
with soundfile.SoundFile("RAVDESS/Actor_01/03-01-03-01-01-01-01.wav") as audio:
    happy_waveform = audio.read(dtype="float32")
    sample_rate = audio.samplerate

with soundfile.SoundFile("RAVDESS/Actor_01/03-01-05-01-01-01-01.wav") as audio:
    angry_waveform = audio.read(dtype="float32")
    # same sample rate

# %% [markdown]
# ##### Visualize the combination of power spectrograms output by STFT w.r.t time:

# %%
stft_spectrum_matrix = librosa.stft(happy_waveform)
plt.figure(figsize=(10, 4))
librosa.display.specshow(
    librosa.amplitude_to_db(np.abs(stft_spectrum_matrix), ref=np.max),
    y_axis="log",
    x_axis="time",
)
plt.title("Happy STFT Power spectrogram")
plt.colorbar(format="%+2.0f dB")
plt.tight_layout()

stft_spectrum_matrix = librosa.stft(angry_waveform)
plt.figure(figsize=(10, 4))
librosa.display.specshow(
    librosa.amplitude_to_db(np.abs(stft_spectrum_matrix), ref=np.max),
    y_axis="log",
    x_axis="time",
)
plt.title("Angry STFT Power spectrogram")
plt.colorbar(format="%+2.0f dB")
plt.tight_layout()

# %% [markdown]
# We're getting somewhere, but we're going to have to go further. We operate under the assumption that features whose interclass differences we can visualize will be good candidates on which to train a neural network. Looks like further transformations on the STFT will yield good features. Since we have a 3 second audio file, STFT spectrograms for these audio samples combine to show the change in frequencies across a 3 second window.

# %% [markdown]
# ###Mel-Frequency Cepstral Coefficients
# We're going to build on the STFT by using the Mel Frequency Cepstral Coefficients (MFCCs) as a feature.
# In brief, MFCC is a mathematical method which transforms the power spectrum of an audio signal to a small number of coefficients representing power of the audio signal in a frequency region (a region of pitch) taken w.r.t. time.
# <br><br>
# In other words, MFC coefficients give us an idea of the changing pitch of an audio signal.
#
# To understand our major feature a little better, we should at least have a vague idea of the math behind it.
# MFCC at its core uses STFT to produce audio power spectrums. We then apply triangular, overlapping window functions to the power spectrograms and take the sum of energy in each window which is essentialy a frequency bin. To determine the number and position of window functions, and width of each frequency bin, we map the frequencies of our audio's power spectrograms to the [Mel scale](https://en.wikipedia.org/wiki/Mel_scale), a nonlinear pitch scale representing the perceived pitch in 'mels' of an audio signal w.r.t. its frequency. The motivation for the mel scale is to account for the way human hearing perceives pitch based on frequency ratios rather than absolute differences in frequencies. The window functions/frequency bins we applied in this step are called mel filterbanks.
#
# Now we can take the log of the sum of power in each mel frequency filterbank. Taking the log power of an audio spectrogram produces a cepstrum - more on this a little later.
#
# ###### The Discrete Cosine Transform
#
# Finally, we apply the discrete cosine transform [(DCT)](https://en.wikipedia.org/wiki/Discrete_cosine_transform) to the log of power in each filterbank. The DCT carries distinguished advantages: Because triangular window functions overlap, the mel filterbank energies are correlated with each other; DCT decorellates the signals; DCT produces coefficients such that usually only the top few coefficients are necessary to represent a signal with fair accuracy, i.e. a compressed representation. **In this way, DCT is quite similar to PCA** - one key difference being that DCT has an absolute definition while PCA is only defined w.r.t. a dataset. For this reason (and a couple others) DCT sees a _huge_ range of applicability: image and audio data compression (read: internet, wireless tech, medicine) and cryptography are most notable. Our MFC coefficients are then the amplitudes of each DCT-transformed log filterbank power, taken w.r.t. time.
#
# Another way to think about MFCC is as a deconvolution method to identify periodic, or resonant structures within an audio signal's frequency space. We can visualize our MFC coefficients by plotting the coefficients provided by each mel filterbank against time.
#
# I've found for this task that 40 filterbanks producing 40 coefficients provide the best accuracy and quick computation.
#
# You can further explore the Mel-Frequency Cepstral Coefficients from
# [this article.](https://medium.com/@derutycsl/intuitive-understanding-of-mfccs-836d36a1f779)

# %% [markdown]
# ###### Visualize our sample's MFC coefficients w.r.t time:

# %%
from matplotlib.colors import Normalize

mfc_coefficients = librosa.feature.mfcc(y=happy_waveform, sr=sample_rate, n_mfcc=40)
plt.figure(figsize=(10, 4))
librosa.display.specshow(
    mfc_coefficients, x_axis="time", norm=Normalize(vmin=-30, vmax=30)
)
plt.colorbar()
plt.yticks(())
plt.ylabel("MFC Coefficient")
plt.title("Happy MFC Coefficients")
plt.tight_layout()

mfc_coefficients = librosa.feature.mfcc(y=angry_waveform, sr=sample_rate, n_mfcc=40)
plt.figure(figsize=(10, 4))
librosa.display.specshow(
    mfc_coefficients, x_axis="time", norm=Normalize(vmin=-30, vmax=30)
)
plt.colorbar()
plt.yticks(())
plt.ylabel("MFC Coefficient")
plt.title("Angry MFC Coefficients")
plt.tight_layout()

# %% [markdown]
# **Positive MFCCs correspond to low-frequency regions of the cepstrum, and negative MFFCs to high-frequency.**
#
# **We see the Angry voice has a much greater proportion of positive MFFCs, corresponding to a lower voice pitch compared to the Happy voice. Makes sense - a happy voice carries a lighter tone and a higher pitch.**

# %% [markdown]
# ##### Quick MFCC Derivation
#
# 1. Take the square of magnitudes in spectrograms produced by STFT to produce audio power spectrograms for short overlapping frames of the audio signal, <br>
# 2. Apply a mel-scale-based transformation, mel filterbanks (triangular window functions) to each STFT power spectrogram and sum the power in each filterbank <br>
# 3. Take the log of each filterbank power <br>
# 4. Take the discrete cosine transform of each log power in each STFT frame, giving us the MFC coefficients - our measure of power at various mel frequencies, corresponding to audible pitch. <br>
#
# Wikipedia has a pretty straight-forward explanation of [MFCCs](https://en.wikipedia.org/wiki/Mel-frequency_cepstrum).

# %% [markdown]
# ### Mel Spectrograms and Mel-Frequency Cepstrums
#
# In deriving our MFCCs, we have also produced an additional feature we can make use of.
# When we mapped the frequencies of a power spectrogram to the mel scale, we produced a Mel Frequency Spectrogram -
# a simple analog of the power spectrogram with the frequency scale in mels.
# We're going to use the Mel Specotrgrogram as a feature of its own.

# %% [markdown]
# ##### Visualize our sample's Mel spectrogram w.r.t time:

# %%
melspectrogram = librosa.feature.melspectrogram(
    y=happy_waveform, sr=sample_rate, n_mels=128, fmax=8000
)
plt.figure(figsize=(10, 4))
librosa.display.specshow(
    librosa.power_to_db(S=melspectrogram, ref=np.mean),
    y_axis="mel",
    fmax=8000,
    x_axis="time",
    norm=Normalize(vmin=-20, vmax=20),
)
plt.colorbar(format="%+2.0f dB", label="Amplitude")
plt.ylabel("Mels")
plt.title("Happy Mel spectrogram")
plt.tight_layout()

melspectrogram = librosa.feature.melspectrogram(
    y=angry_waveform, sr=sample_rate, n_mels=128, fmax=8000
)
plt.figure(figsize=(10, 4))
librosa.display.specshow(
    librosa.power_to_db(S=melspectrogram, ref=np.mean),
    y_axis="mel",
    fmax=8000,
    x_axis="time",
    norm=Normalize(vmin=-20, vmax=20),
)
plt.colorbar(format="%+2.0f dB", label="Amplitude")
plt.ylabel("Mels")
plt.title("Angry Mel spectrogram")
plt.tight_layout()

# %% [markdown]
# **The Angry voice produces sharper transitions between mel frequency peaks compared to the Happy voice, which has smoother pitch transitions. That makes intuitive sense - an Angry voice has sharp transitions while a happy voice is more steady and pleasing to the ears. Mel spectrograms will make another good feature.**
#
# What about the cepstrum? When we took the log of the spectral amplitudes in a Mel-scaled power spectrogram, we could have plotted that result as a time series and produced what is known as a 'mel-frequency cepstrum', now in the 'quefrency' domain, so confusingly named because we have applied a transformation to an audio signal in its frequency domain, but have plotted it as a time series - not quite in the frequency domain, not quite in the time domain. In the cepstrum, we observe a peak wherever there is a periodic element in the original audio signal. We've actually already used the the mel-frequency cepstrum (MFC) as a feature, since that is precisely the source of our MFC coefficients. Again, Wikipedia has a fairly palatable explanation of the [cepstrum](https://en.wikipedia.org/wiki/Cepstrum).
#
# Below is an excellent visualization of the transformations between waveform, spectrogram, mel spectrogram, and MFCCs plotted as time series.
# The vertical frame in each graph represents a single STFT frame.<br>

# %% [markdown]
# ![mfcc.gif](data:image/gif;base64,...)

# %% [markdown]
# ### The Chromagram
#
# To extract an additional feature, we're going to build a chromagram on each power spectrogram computed by STFT. A chromagram is a representation of an audio signal w.r.t. time, mapping audio signal to a pitch class.
# Most often, we map to the 12 standard pitch classes (i.e. the musical scale CDEFGAB + 5 semitones gives us 12 pitch classes).
# Again, wikipedia has a short and sweet [explanation](https://en.wikipedia.org/wiki/Chroma_feature).

# %% [markdown]
# ##### Visualize the chromagram for our sample audio:

# %%
chromagram = librosa.feature.chroma_stft(y=happy_waveform, sr=sample_rate)
plt.figure(figsize=(10, 4))
librosa.display.specshow(chromagram, y_axis="chroma", x_axis="time")
plt.colorbar(label="Relative Intensity")
plt.title("Happy Chromagram")
plt.tight_layout()

chromagram = librosa.feature.chroma_stft(y=angry_waveform, sr=sample_rate)
plt.figure(figsize=(10, 4))
librosa.display.specshow(chromagram, y_axis="chroma", x_axis="time")
plt.colorbar(label="Relative Intensity")
plt.title("Angry Chromagram")
plt.tight_layout()

# %%
print(chromagram.shape)
# Out:
# (12, 363)

# %% [markdown]
# **The pitch distribution of the Angry voice has a much lower dispersion compared to the Happy voice, whose pitch has a higher dispersion at any point in time. This makes intuitive sense considering the tone of an angry voice is more intense and "snappy" compared to a happy voice, which is smoother to the ears - here's a good explanation as to why. This should make a good feature.**

# %% [markdown]
# ### Feature Extraction
#
# We're going to take full advantage of librosa, a Python library enabling audio analysis and feature extraction.
# Librosa abstracts away all the math and most of the details of mel spectrorgams, chromagrams, and MFCC.
# Although closely related, we're going to take the Mel Spectrogram, MFCC, and chromagrams of each audio file as separate features to try
# and have bit more discriminatory power between samples. <br>
#
# Let's build our feature extraction functions to get a chromagram, a mel spectorgram, and MFC coefficients for each of our audio files. Because the chromagram, mel spectrogram and MFCCs are calculated on audio frames produced by STFT, we're going to get a matrix back from each function, so we'll take the mean of those matrices to produce a single feature array for each feature and each audio sample, i.e. 3 feature arrays per audio sample.
#
# **Chromagram**: Will produce 12 features; One for each of 12 pitch classes
#
# **Mel Spectrogram**: Will produce 128 features; We've defined the number of mel frequency bands at n_mels=128
#
# **MFCC**: Will produce 40 MFCCs; I've set the number of coefficients to return at n_mfcc=40 which I found to work well

# %%
import librosa


def feature_chromagram(waveform, sample_rate):
    # STFT computed here explicitly; mel spectrogram and MFCC functions do this under the hood
    stft_spectrogram = np.abs(librosa.stft(waveform))
    # print(stft_spectrogram.shape)
    # Produce the chromagram for all STFT frames and get the mean of each column of the resulting matrix to create a feature array
    chromagram = np.mean(
        librosa.feature.chroma_stft(S=stft_spectrogram, sr=sample_rate).T, axis=0
    )
    # print(chromagram.shape)
    return chromagram


def feature_melspectrogram(waveform, sample_rate):
    # Produce the mel spectrogram for all STFT frames and get the mean of each column of the resulting matrix to create a feature array
    # Using 8khz as upper frequency bound should be enough for most speech classification tasks
    melspectrogram = np.mean(
        librosa.feature.melspectrogram(
            y=waveform, sr=sample_rate, n_mels=128, fmax=8000
        ).T,
        axis=0,
    )
    return melspectrogram


def feature_mfcc(waveform, sample_rate):
    # Compute the MFCCs for all STFT frames and get the mean of each column of the resulting matrix to create a feature array
    # 40 filterbanks = 40 coefficients
    mfc_coefficients = np.mean(
        librosa.feature.mfcc(y=waveform, sr=sample_rate, n_mfcc=40).T, axis=0
    )
    return mfc_coefficients

# %% [markdown]
# We're going to wrap our feature extraction functions so we only have to load each audio file once. After extracting our 3 audio features as NumPy arrays representing a time series, we're going to
# stack them horizontally to create a single feature array.

# %%
def get_features(file):
    # load an individual soundfile
    with soundfile.SoundFile(file) as audio:
        waveform = audio.read(dtype="float32")
        sample_rate = audio.samplerate
        # compute features of soundfile
        chromagram = feature_chromagram(waveform, sample_rate)
        melspectrogram = feature_melspectrogram(waveform, sample_rate)
        mfc_coefficients = feature_mfcc(waveform, sample_rate)
        feature_matrix = np.array([])

        # use np.hstack to stack our feature arrays horizontally to create a feature matrix
        feature_matrix = np.hstack((chromagram, melspectrogram, mfc_coefficients))

        return feature_matrix

# %% [markdown]
# ### Load the Dataset and Compute Features
#
# We have to understand the labelling of the RAVDESS dataset to find the ground truth emotion for each sample.
# Each file is labelled with 7 numbers delimited by a "-".
# Most of the numbers describe metadata about the audio samples such as their format (video and/or audio),
# whether the audio is a song or statement, which of two statements is being read and by which actor.
#
# The third and fourth numbers pertain to the emotional quality of each sample. The third number is in the range of 1-8 with each number representing an emotion.
# The fourth number is either 1 or 2, representing normal (1) or strong (2) emotional intensity.
#
# We're going to define a dictionary based on the third number (emotion) and assign an emotion to each number as specified by the RAVDESS dataset:

# %%
# Emotions in the RAVDESS dataset
emotions = {
    "01": "neutral",
    "02": "calm",
    "03": "happy",
    "04": "sad",
    "05": "angry",
    "06": "fearful",
    "07": "disgust",
    "08": "surprised",
}

# %% [markdown]
# Finally, let's load our entire dataset and compute the features of each audio file:

# %%
import os, glob


def load_data():
    X, y = [], []
    count = 0
    for file in glob.glob(
        "/content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_*/*.wav"
    ):
        file_name = os.path.basename(file)
        # print(file_name)
        # print(file_name.split("-")[2])
        emotion = emotions[(file_name.split("-")[2])]
        # print(emotion)
        features = get_features(file)
        X.append(features)
        y.append(emotion)
        count += 1
        # '\r' + end='' results in printing over same line
        print("\r" + f" Processed {count}/{1435} audio samples", end=" ")
    # Return arrays to plug into sklearn's cross-validation algorithms
    return np.array(X), np.array(y)

# %% [markdown]
# Compute the feature matrix and read the emotion labels for the entire dataset.
# Note that our regressor (independent/explanatory variable), usually denoted X, is named 'features', and our regressand (dependent variable), usually denoted y, is named 'emotions'.

# %%
features, emotions = load_data()
# Out:
# Streaming output truncated to the last 5000 lines.
# (128,)
# (40,)
# (180,)
#  Processed 436/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_04/03-01-03-02-01-02-04.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 437/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_04/03-01-02-02-01-01-04.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 438/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_04/03-01-03-02-02-01-04.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 439/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_04/03-01-05-01-01-01-04.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 440/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_04/03-01-06-01-02-02-04.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 441/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_04/03-01-06-01-01-01-04.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 442/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_04/03-01-04-02-01-01-04.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 443/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_04/03-01-07-01-01-01-04.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 444/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_04/03-01-07-01-02-02-04.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 445/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_04/03-01-06-02-02-01-04.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 446/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_04/03-01-04-01-02-02-04.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 447/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_04/03-01-04-01-02-01-04.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 448/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_04/03-01-06-02-01-02-04.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 449/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_04/03-01-05-01-02-01-04.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 450/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_04/03-01-05-02-01-02-04.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 451/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_04/03-01-04-02-01-02-04.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 452/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_04/03-01-06-02-02-02-04.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 453/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_04/03-01-05-02-02-01-04.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 454/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_04/03-01-04-02-02-01-04.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 455/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_04/03-01-05-01-01-02-04.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 456/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_04/03-01-04-02-02-02-04.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 457/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_04/03-01-05-02-01-01-04.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 458/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_04/03-01-05-02-02-02-04.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 459/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_04/03-01-07-01-01-02-04.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 460/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_04/03-01-07-01-02-01-04.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 461/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_04/03-01-06-01-02-01-04.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 462/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_04/03-01-05-01-02-02-04.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 463/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_04/03-01-06-02-01-01-04.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 464/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_04/03-01-06-01-01-02-04.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 465/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_04/03-01-08-01-01-01-04.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 466/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_04/03-01-07-02-02-01-04.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 467/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_04/03-01-08-01-02-02-04.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 468/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_04/03-01-08-01-02-01-04.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 469/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_04/03-01-07-02-01-02-04.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 470/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_04/03-01-07-02-01-01-04.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 471/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_04/03-01-08-02-01-02-04.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 472/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_04/03-01-08-02-01-01-04.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 473/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_04/03-01-08-02-02-02-04.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 474/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_04/03-01-07-02-02-02-04.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 475/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_04/03-01-08-02-02-01-04.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 476/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_04/03-01-08-01-01-02-04.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 477/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_06/03-01-01-01-01-01-06.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 478/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_06/03-01-01-01-01-02-06.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 479/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_06/03-01-03-01-01-01-06.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 480/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_06/03-01-04-01-01-01-06.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 481/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_06/03-01-04-01-01-02-06.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 482/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_06/03-01-02-01-01-01-06.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 483/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_06/03-01-01-01-02-01-06.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 484/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_06/03-01-02-01-02-02-06.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 485/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_06/03-01-03-02-01-02-06.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 486/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_06/03-01-01-01-02-02-06.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 487/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_06/03-01-02-02-01-01-06.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 488/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_06/03-01-03-02-02-02-06.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 489/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_06/03-01-02-02-01-02-06.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 490/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_06/03-01-03-01-02-02-06.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 491/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_06/03-01-04-01-02-02-06.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 492/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_06/03-01-04-02-01-02-06.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 493/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_06/03-01-03-01-02-01-06.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 494/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_06/03-01-04-02-01-01-06.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 495/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_06/03-01-02-01-02-01-06.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 496/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_06/03-01-03-02-01-01-06.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 497/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_06/03-01-02-01-01-02-06.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 498/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_06/03-01-03-02-02-01-06.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 499/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_06/03-01-02-02-02-02-06.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 500/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_06/03-01-02-02-02-01-06.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 501/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_06/03-01-04-01-02-01-06.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 502/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_06/03-01-03-01-01-02-06.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 503/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_06/03-01-05-02-01-02-06.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 504/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_06/03-01-05-01-01-01-06.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 505/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_06/03-01-06-02-01-01-06.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 506/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_06/03-01-07-01-01-01-06.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 507/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_06/03-01-05-02-02-01-06.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 508/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_06/03-01-06-01-02-02-06.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 509/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_06/03-01-07-01-01-02-06.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 510/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_06/03-01-06-02-01-02-06.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 511/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_06/03-01-07-02-02-01-06.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 512/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_06/03-01-04-02-02-01-06.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 513/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_06/03-01-05-01-02-01-06.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 514/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_06/03-01-07-01-02-02-06.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 515/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_06/03-01-06-01-01-02-06.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 516/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_06/03-01-05-01-01-02-06.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 517/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_06/03-01-05-01-02-02-06.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 518/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_06/03-01-06-01-02-01-06.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 519/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_06/03-01-07-02-01-02-06.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 520/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_06/03-01-07-01-02-01-06.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 521/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_06/03-01-06-02-02-02-06.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 522/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_06/03-01-06-02-02-01-06.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 523/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_06/03-01-07-02-01-01-06.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 524/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_06/03-01-05-02-01-01-06.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 525/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_06/03-01-06-01-01-01-06.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 526/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_06/03-01-05-02-02-02-06.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 527/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_06/03-01-04-02-02-02-06.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 528/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_06/03-01-08-02-02-01-06.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 529/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_06/03-01-08-01-01-01-06.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 530/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_06/03-01-08-01-01-02-06.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 531/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_06/03-01-08-02-01-01-06.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 532/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_06/03-01-07-02-02-02-06.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 533/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_06/03-01-08-01-02-01-06.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 534/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_06/03-01-08-02-02-02-06.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 535/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_06/03-01-08-01-02-02-06.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 536/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_06/03-01-08-02-01-02-06.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 537/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_09/03-01-01-01-02-02-09.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 538/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_09/03-01-02-01-01-01-09.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 539/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_09/03-01-01-01-01-01-09.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 540/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_09/03-01-02-01-02-02-09.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 541/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_09/03-01-02-02-02-01-09.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 542/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_09/03-01-01-01-02-01-09.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 543/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_09/03-01-03-01-01-02-09.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 544/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_09/03-01-03-01-02-02-09.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 545/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_09/03-01-02-01-02-01-09.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 546/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_09/03-01-02-02-01-01-09.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 547/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_09/03-01-03-01-02-01-09.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 548/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_09/03-01-02-01-01-02-09.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 549/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_09/03-01-03-02-01-02-09.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 550/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_09/03-01-03-02-02-01-09.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 551/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_09/03-01-03-02-02-02-09.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 552/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_09/03-01-02-02-01-02-09.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 553/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_09/03-01-03-01-01-01-09.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 554/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_09/03-01-01-01-01-02-09.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 555/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_09/03-01-02-02-02-02-09.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 556/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_09/03-01-03-02-01-01-09.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 557/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_09/03-01-04-01-01-02-09.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 558/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_09/03-01-04-02-02-01-09.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 559/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_09/03-01-05-02-01-02-09.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 560/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_09/03-01-06-02-01-01-09.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 561/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_09/03-01-07-01-01-02-09.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 562/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_09/03-01-05-02-01-01-09.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 563/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_09/03-01-06-01-01-02-09.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 564/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_09/03-01-04-02-01-02-09.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 565/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_09/03-01-06-02-02-02-09.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 566/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_09/03-01-05-01-02-01-09.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 567/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_09/03-01-04-01-02-01-09.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 568/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_09/03-01-05-02-02-02-09.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 569/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_09/03-01-05-02-02-01-09.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 570/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_09/03-01-04-02-02-02-09.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 571/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_09/03-01-06-01-01-01-09.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 572/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_09/03-01-04-02-01-01-09.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 573/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_09/03-01-06-01-02-01-09.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 574/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_09/03-01-05-01-02-02-09.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 575/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_09/03-01-04-01-02-02-09.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 576/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_09/03-01-07-01-01-01-09.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 577/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_09/03-01-06-01-02-02-09.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 578/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_09/03-01-06-02-02-01-09.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 579/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_09/03-01-05-01-01-01-09.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 580/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_09/03-01-04-01-01-01-09.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 581/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_09/03-01-05-01-01-02-09.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 582/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_09/03-01-06-02-01-02-09.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 583/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_09/03-01-07-02-01-01-09.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 584/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_09/03-01-08-02-01-01-09.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 585/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_09/03-01-07-02-02-01-09.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 586/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_09/03-01-07-02-01-02-09.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 587/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_09/03-01-08-02-01-02-09.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 588/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_09/03-01-07-01-02-02-09.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 589/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_09/03-01-08-01-01-02-09.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 590/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_09/03-01-07-01-02-01-09.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 591/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_09/03-01-08-02-02-02-09.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 592/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_09/03-01-08-01-02-02-09.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 593/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_09/03-01-08-01-02-01-09.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 594/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_09/03-01-08-01-01-01-09.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 595/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_09/03-01-07-02-02-02-09.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 596/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_09/03-01-08-02-02-01-09.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 597/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_20/03-01-01-01-01-01-20.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 598/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_20/03-01-01-01-01-02-20.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 599/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_20/03-01-01-01-02-01-20.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 600/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_20/03-01-03-01-01-02-20.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 601/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_20/03-01-02-02-02-02-20.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 602/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_20/03-01-04-01-02-02-20.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 603/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_20/03-01-02-01-02-01-20.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 604/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_20/03-01-04-02-01-02-20.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 605/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_20/03-01-04-02-01-01-20.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 606/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_20/03-01-03-02-01-01-20.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 607/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_20/03-01-03-02-01-02-20.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 608/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_20/03-01-01-01-02-02-20.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 609/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_20/03-01-04-01-02-01-20.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 610/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_20/03-01-04-02-02-01-20.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 611/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_20/03-01-02-02-01-01-20.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 612/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_20/03-01-02-01-01-02-20.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 613/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_20/03-01-04-01-01-02-20.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 614/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_20/03-01-03-02-02-01-20.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 615/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_20/03-01-04-01-01-01-20.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 616/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_20/03-01-03-01-02-02-20.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 617/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_20/03-01-02-02-01-02-20.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 618/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_20/03-01-02-01-01-01-20.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 619/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_20/03-01-02-02-02-01-20.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 620/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_20/03-01-03-01-01-01-20.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 621/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_20/03-01-02-01-02-02-20.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 622/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_20/03-01-03-02-02-02-20.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 623/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_20/03-01-05-02-02-02-20.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 624/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_20/03-01-07-01-01-02-20.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 625/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_20/03-01-07-02-02-01-20.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 626/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_20/03-01-05-01-01-01-20.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 627/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_20/03-01-05-01-02-02-20.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 628/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_20/03-01-05-01-01-02-20.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 629/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_20/03-01-06-02-01-02-20.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 630/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_20/03-01-04-02-02-02-20.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 631/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_20/03-01-07-01-02-02-20.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 632/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_20/03-01-06-01-02-01-20.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 633/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_20/03-01-06-02-02-02-20.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 634/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_20/03-01-05-02-01-01-20.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 635/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_20/03-01-06-02-02-01-20.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 636/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_20/03-01-06-02-01-01-20.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 637/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_20/03-01-07-01-02-01-20.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 638/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_20/03-01-07-02-01-02-20.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 639/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_20/03-01-07-02-01-01-20.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 640/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_20/03-01-05-02-01-02-20.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 641/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_20/03-01-05-01-02-01-20.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 642/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_20/03-01-06-01-01-01-20.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 643/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_20/03-01-06-01-02-02-20.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 644/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_20/03-01-07-01-01-01-20.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 645/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_20/03-01-05-02-02-01-20.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 646/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_20/03-01-07-02-02-02-20.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 647/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_20/03-01-08-01-02-01-20.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 648/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_20/03-01-08-01-02-02-20.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 649/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_20/03-01-08-01-01-01-20.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 650/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_20/03-01-08-01-01-02-20.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 651/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_20/03-01-08-02-02-02-20.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 652/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_20/03-01-08-02-01-02-20.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 653/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_20/03-01-08-02-01-01-20.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 654/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_20/03-01-08-02-02-01-20.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 655/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_18/03-01-01-01-01-01-18.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 656/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_18/03-01-04-01-02-01-18.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 657/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_18/03-01-02-02-02-01-18.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 658/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_18/03-01-03-02-01-01-18.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 659/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_18/03-01-02-02-01-01-18.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 660/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_18/03-01-04-01-02-02-18.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 661/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_18/03-01-02-01-02-01-18.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 662/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_18/03-01-02-01-02-02-18.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 663/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_18/03-01-02-02-01-02-18.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 664/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_18/03-01-04-02-01-02-18.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 665/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_18/03-01-02-01-01-02-18.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 666/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_18/03-01-03-01-01-01-18.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 667/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_18/03-01-03-02-02-01-18.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 668/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_18/03-01-02-02-02-02-18.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 669/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_18/03-01-03-01-01-02-18.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 670/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_18/03-01-01-01-02-01-18.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 671/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_18/03-01-01-01-02-02-18.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 672/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_18/03-01-04-02-01-01-18.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 673/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_18/03-01-03-02-02-02-18.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 674/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_18/03-01-03-01-02-02-18.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 675/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_18/03-01-04-01-01-01-18.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 676/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_18/03-01-03-01-02-01-18.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 677/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_18/03-01-04-01-01-02-18.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 678/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_18/03-01-01-01-01-02-18.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 679/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_18/03-01-03-02-01-02-18.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 680/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_18/03-01-02-01-01-01-18.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 681/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_18/03-01-07-01-02-01-18.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 682/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_18/03-01-07-01-01-01-18.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 683/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_18/03-01-07-01-01-02-18.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 684/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_18/03-01-05-01-02-01-18.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 685/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_18/03-01-05-02-02-02-18.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 686/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_18/03-01-06-01-01-02-18.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 687/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_18/03-01-06-02-01-02-18.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 688/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_18/03-01-07-02-01-01-18.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 689/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_18/03-01-06-02-02-01-18.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 690/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_18/03-01-04-02-02-02-18.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 691/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_18/03-01-07-01-02-02-18.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 692/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_18/03-01-06-01-01-01-18.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 693/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_18/03-01-06-01-02-01-18.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 694/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_18/03-01-05-02-02-01-18.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 695/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_18/03-01-05-01-01-01-18.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 696/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_18/03-01-05-02-01-01-18.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 697/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_18/03-01-06-02-02-02-18.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 698/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_18/03-01-05-01-02-02-18.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 699/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_18/03-01-05-01-01-02-18.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 700/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_18/03-01-06-01-02-02-18.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 701/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_18/03-01-06-02-01-01-18.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 702/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_18/03-01-04-02-02-01-18.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 703/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_18/03-01-07-02-01-02-18.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 704/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_18/03-01-05-02-01-02-18.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 705/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_18/03-01-08-01-01-01-18.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 706/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_18/03-01-08-02-02-01-18.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 707/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_18/03-01-08-02-01-02-18.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 708/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_18/03-01-08-02-01-01-18.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 709/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_18/03-01-08-02-02-02-18.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 710/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_18/03-01-07-02-02-01-18.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 711/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_18/03-01-08-01-02-02-18.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 712/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_18/03-01-08-01-01-02-18.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 713/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_18/03-01-07-02-02-02-18.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 714/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_18/03-01-08-01-02-01-18.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 715/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_12/03-01-03-01-01-01-12.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 716/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_12/03-01-02-02-02-02-12.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 717/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_12/03-01-02-01-01-01-12.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 718/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_12/03-01-02-01-02-02-12.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 719/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_12/03-01-01-01-02-01-12.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 720/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_12/03-01-01-01-01-01-12.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 721/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_12/03-01-02-02-01-02-12.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 722/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_12/03-01-03-01-01-02-12.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 723/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_12/03-01-01-01-02-02-12.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 724/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_12/03-01-02-02-02-01-12.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 725/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_12/03-01-02-02-01-01-12.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 726/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_12/03-01-02-01-01-02-12.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 727/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_12/03-01-01-01-01-02-12.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 728/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_12/03-01-02-01-02-01-12.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 729/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_12/03-01-04-02-02-01-12.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 730/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_12/03-01-03-02-02-02-12.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 731/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_12/03-01-03-02-02-01-12.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 732/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_12/03-01-04-01-01-02-12.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 733/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_12/03-01-06-01-01-02-12.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 734/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_12/03-01-05-02-01-02-12.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 735/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_12/03-01-05-02-02-01-12.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 736/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_12/03-01-03-02-01-02-12.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 737/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_12/03-01-04-02-01-02-12.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 738/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_12/03-01-05-02-02-02-12.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 739/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_12/03-01-04-02-01-01-12.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 740/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_12/03-01-04-01-02-02-12.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 741/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_12/03-01-04-02-02-02-12.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 742/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_12/03-01-04-01-01-01-12.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 743/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_12/03-01-06-01-01-01-12.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 744/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_12/03-01-05-02-01-01-12.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 745/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_12/03-01-04-01-02-01-12.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 746/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_12/03-01-03-02-01-01-12.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 747/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_12/03-01-05-01-02-02-12.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 748/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_12/03-01-03-01-02-01-12.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 749/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_12/03-01-06-01-02-01-12.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 750/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_12/03-01-05-01-01-01-12.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 751/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_12/03-01-03-01-02-02-12.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 752/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_12/03-01-05-01-02-01-12.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 753/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_12/03-01-05-01-01-02-12.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 754/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_12/03-01-07-02-01-02-12.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 755/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_12/03-01-06-02-02-02-12.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 756/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_12/03-01-08-02-01-02-12.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 757/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_12/03-01-07-02-02-01-12.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 758/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_12/03-01-07-01-02-02-12.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 759/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_12/03-01-07-01-02-01-12.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 760/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_12/03-01-08-01-01-02-12.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 761/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_12/03-01-08-02-02-01-12.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 762/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_12/03-01-08-02-02-02-12.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 763/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_12/03-01-08-01-01-01-12.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 764/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_12/03-01-07-02-01-01-12.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 765/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_12/03-01-07-01-01-01-12.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 766/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_12/03-01-08-02-01-01-12.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 767/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_12/03-01-06-01-02-02-12.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 768/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_12/03-01-06-02-02-01-12.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 769/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_12/03-01-08-01-02-02-12.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 770/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_12/03-01-06-02-01-02-12.wav
# (12,)
# (128,)
# (40,)
# (180,)
# ...
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 1325/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_24/03-01-04-02-01-01-24.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 1326/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_24/03-01-04-01-01-02-24.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 1327/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_24/03-01-03-02-02-01-24.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 1328/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_24/03-01-03-02-01-02-24.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 1329/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_24/03-01-03-01-01-02-24.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 1330/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_24/03-01-03-01-01-01-24.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 1331/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_24/03-01-02-02-01-02-24.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 1332/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_24/03-01-03-01-02-01-24.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 1333/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_24/03-01-02-02-02-02-24.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 1334/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_24/03-01-02-02-02-01-24.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 1335/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_24/03-01-03-01-02-02-24.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 1336/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_24/03-01-04-02-01-02-24.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 1337/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_24/03-01-05-01-01-02-24.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 1338/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_24/03-01-05-01-01-01-24.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 1339/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_24/03-01-05-01-02-01-24.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 1340/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_24/03-01-04-01-02-02-24.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 1341/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_24/03-01-04-01-02-01-24.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 1342/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_24/03-01-02-01-02-02-24.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 1343/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_24/03-01-03-02-02-02-24.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 1344/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_24/03-01-04-02-02-01-24.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 1345/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_24/03-01-04-01-01-01-24.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 1346/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_24/03-01-06-02-01-02-24.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 1347/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_24/03-01-08-01-01-02-24.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 1348/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_24/03-01-07-01-01-02-24.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 1349/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_24/03-01-06-02-02-01-24.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 1350/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_24/03-01-07-01-02-01-24.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 1351/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_24/03-01-05-02-01-01-24.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 1352/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_24/03-01-07-01-01-01-24.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 1353/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_24/03-01-06-01-01-02-24.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 1354/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_24/03-01-08-01-02-01-24.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 1355/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_24/03-01-07-02-02-02-24.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 1356/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_24/03-01-06-02-01-01-24.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 1357/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_24/03-01-06-01-02-01-24.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 1358/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_24/03-01-05-01-02-02-24.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 1359/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_24/03-01-07-02-02-01-24.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 1360/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_24/03-01-05-02-02-02-24.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 1361/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_24/03-01-08-01-01-01-24.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 1362/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_24/03-01-06-01-02-02-24.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 1363/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_24/03-01-07-01-02-02-24.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 1364/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_24/03-01-05-02-01-02-24.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 1365/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_24/03-01-07-02-01-01-24.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 1366/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_24/03-01-07-02-01-02-24.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 1367/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_24/03-01-06-02-02-02-24.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 1368/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_24/03-01-06-01-01-01-24.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 1369/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_24/03-01-05-02-02-01-24.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 1370/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_24/03-01-08-02-01-01-24.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 1371/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_24/03-01-08-02-01-02-24.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 1372/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_24/03-01-08-02-02-02-24.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 1373/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_24/03-01-08-02-02-01-24.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 1374/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_24/03-01-08-01-02-02-24.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 1375/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_21/03-01-02-01-01-01-21.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 1376/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_21/03-01-02-02-01-01-21.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 1377/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_21/03-01-02-02-01-02-21.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 1378/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_21/03-01-02-01-02-01-21.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 1379/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_21/03-01-03-01-02-02-21.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 1380/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_21/03-01-03-01-02-01-21.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 1381/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_21/03-01-01-01-02-02-21.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 1382/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_21/03-01-01-01-02-01-21.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 1383/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_21/03-01-02-02-02-01-21.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 1384/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_21/03-01-03-01-01-01-21.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 1385/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_21/03-01-02-02-02-02-21.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 1386/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_21/03-01-03-01-01-02-21.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 1387/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_21/03-01-02-01-02-02-21.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 1388/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_21/03-01-02-01-01-02-21.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 1389/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_21/03-01-01-01-01-02-21.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 1390/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_21/03-01-01-01-01-01-21.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 1391/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_21/03-01-05-02-01-02-21.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 1392/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_21/03-01-05-01-01-02-21.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 1393/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_21/03-01-04-02-01-02-21.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 1394/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_21/03-01-04-01-02-02-21.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 1395/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_21/03-01-06-01-02-01-21.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 1396/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_21/03-01-04-01-01-01-21.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 1397/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_21/03-01-03-02-01-02-21.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 1398/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_21/03-01-05-01-02-02-21.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 1399/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_21/03-01-05-02-01-01-21.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 1400/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_21/03-01-03-02-02-01-21.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 1401/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_21/03-01-05-02-02-01-21.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 1402/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_21/03-01-06-01-02-02-21.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 1403/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_21/03-01-05-02-02-02-21.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 1404/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_21/03-01-03-02-01-01-21.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 1405/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_21/03-01-04-01-01-02-21.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 1406/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_21/03-01-05-01-02-01-21.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 1407/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_21/03-01-04-02-02-02-21.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 1408/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_21/03-01-05-01-01-01-21.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 1409/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_21/03-01-04-02-01-01-21.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 1410/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_21/03-01-06-01-01-01-21.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 1411/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_21/03-01-04-02-02-01-21.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 1412/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_21/03-01-06-01-01-02-21.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 1413/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_21/03-01-03-02-02-02-21.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 1414/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_21/03-01-04-01-02-01-21.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 1415/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_21/03-01-08-02-02-01-21.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 1416/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_21/03-01-07-01-02-02-21.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 1417/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_21/03-01-08-02-02-02-21.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 1418/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_21/03-01-07-02-01-02-21.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 1419/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_21/03-01-08-01-01-02-21.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 1420/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_21/03-01-08-02-01-01-21.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 1421/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_21/03-01-08-02-01-02-21.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 1422/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_21/03-01-08-01-02-01-21.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 1423/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_21/03-01-07-01-01-01-21.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 1424/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_21/03-01-06-02-01-01-21.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 1425/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_21/03-01-07-02-02-01-21.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 1426/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_21/03-01-06-02-02-01-21.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 1427/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_21/03-01-06-02-02-02-21.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 1428/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_21/03-01-07-01-02-01-21.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 1429/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_21/03-01-08-01-02-02-21.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 1430/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_21/03-01-08-01-01-01-21.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 1431/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_21/03-01-07-02-02-02-21.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 1432/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_21/03-01-06-02-01-02-21.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 1433/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_21/03-01-07-02-01-01-21.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 1434/1440 audio samples /content/drive/MyDrive/Audio_Speech_Actors_01-24/Actor_21/03-01-07-01-01-02-21.wav
# (12,)
# (128,)
# (40,)
# (180,)
#  Processed 1435/1440 audio samples

# %%
features
# Out:
# array([], dtype=float64)

# %% [markdown]
# Let's see what the features we extracted look like:

# %%
print(f"\nAudio samples represented: {features.shape[0]}")
print(f"Numerical features extracted per sample: {features.shape[1]}")
features_df = pd.DataFrame(features)  # make it pretty for display
features_df
# Out:
# Audio samples represented: 1435
# Numerical features extracted per sample: 180
#            0         1         2         3         4         5         6    \
# 0     0.617466  0.576461  0.569040  0.609814  0.654684  0.701384  0.735561
# 1     0.623919  0.574488  0.517403  0.513132  0.550291  0.568414  0.568268
# 2     0.503092  0.500758  0.474714  0.501313  0.573869  0.604987  0.556901
# 3     0.677821  0.616982  0.615782  0.621085  0.626168  0.646080  0.691546
# 4     0.512131  0.457755  0.478713  0.520813  0.516800  0.540460  0.621741
# ...        ...       ...       ...       ...       ...       ...       ...
# 1430  0.639658  0.634329  0.655832  0.664202  0.676282  0.709708  0.767232
# 1431  0.685525  0.688144  0.690283  0.755877  0.820215  0.821966  0.801405
# 1432  0.645078  0.669609  0.699656  0.684427  0.701292  0.757168  0.760762
# 1433  0.649360  0.663266  0.667998  0.726094  0.785460  0.802168  0.792829
# 1434  0.672758  0.657547  0.655824  0.738616  0.800489  0.836885  0.823467
#
#            7         8         9    ...       170       171       172  \
# 0     0.717063  0.728129  0.702318  ... -3.581316 -0.467617 -3.222230
# 1     0.579836  0.644346  0.689928  ...  1.126486  3.953426  1.156003
# 2     0.569272  0.661844  0.735248  ... -1.041501  1.307965  0.363679
# 3     0.685554  0.722938  0.696742  ... -1.149269  1.404988 -1.316433
# 4     0.673709  0.763157  0.709443  ... -2.535597  1.397879 -0.517047
# ...        ...       ...       ...  ...       ...       ...       ...
# 1430  0.797122  0.820559  0.776192  ... -0.982834 -3.941438 -1.568234
# 1431  0.782814  0.742455  0.718314  ... -1.831094 -1.542663 -0.201960
# 1432  0.719712  0.724569  0.740335  ... -1.366737 -3.429536 -2.701700
# 1433  0.793844  0.756972  0.711162  ... -1.713587 -1.361203 -1.172765
# 1434  0.817913  0.795753  0.723377  ... -1.962599 -2.106002 -1.536456
#
#            173       174       175        176       177       178       179
# 0     0.313375  3.955157 -0.183977   1.367951  2.254531 -0.198084  4.343905
# 1     6.056956  5.954752  3.322112   6.695466  4.928186  3.682733  4.037534
# 2     5.471038  7.249944  8.715325  10.268682  9.382307  6.510154  2.336356
# 3     3.550398  3.366586  0.352723   2.582228  2.148702  1.180273  4.521074
# 4     5.022032  7.575803  4.056076   4.256593  3.530471  4.952089  5.641845
# ...        ...       ...       ...        ...       ...       ...       ...
# 1430 -0.911202 -1.684332 -0.180414  -1.289849 -1.290700 -1.424315 -1.072947
# 1431 -0.480004  0.557405  0.270044  -1.388379  0.114239 -0.770378 -0.304880
# 1432 -2.545479 -2.373800 -1.142668  -0.932497 -2.504158 -4.573127 -2.491820
# 1433 -0.611027  0.773962 -0.374147  -1.157781 -0.118639 -1.210494 -0.525753
# 1434 -0.911090 -0.464921 -0.739407  -1.509439 -0.321723 -1.782737 -0.692373
#
# [1435 rows x 180 columns]

# %% [markdown]
# We have a matrix of dim 1435 x 180. Looks good - 1435 audio samples, one per row, with a series of
# 180 numerical features for each sample.
#
# **Each of the 1435 feature arrays has 180 features composed of 12 chromagram pitch classes + 128 mel spectrogram bands + 40 MFC coefficients.**

# %% [markdown]
# Let's see the class balance of our dataset:

# %%
# plot emotions
plt.figure(figsize=(35, 4))
plt.subplot(1, 3, 1)
# np.unique returns ordered list of unique elements and count of each element
emotion_list, count = np.unique(emotions, return_counts=True)
plt.bar(x=range(8), height=count)
plt.xticks(ticks=range(8), labels=[emotion for emotion in emotion_list], fontsize=10)
plt.xlabel("Emotion")
plt.tick_params(labelsize=16)
plt.ylabel("Number of Samples")
plt.show()

# %% [markdown]
# **Great, the classes appear to be balanced. That makes the task easier.** All emotions _except_ the neutral class have a "strong" intensity so there are half as many neutral samples. That might have an impact.

# %% [markdown]
# ### Feature Scaling
#
# To properly train most machine learning models on _most_ datasets, we first need to scale our features. **This is crucial for models which compute distances between data, and especially critical for DNNs**: If there is a difference in the variance of features simply because of their possible range of values, then a model will learn that the features with the greatest variance are the most important. However, **differences in the variance of unscaled features belonging to different and unknown distributions is an inappropriate measure of importance.** Let's check our features' properties:

# %%
# We would usually use df.describe(), but it provides a bit of a mess of information we don't need at the moment.
def print_features(df):
    # Check chromagram feature values
    features_df_chromagram = df.loc[:, :11]
    chroma_min = features_df_chromagram.min().min()
    chroma_max = features_df_chromagram.max().max()
    # stack all features into a single series so we don't get a mean of means or stdev of stdevs
    chroma_mean = features_df_chromagram.stack().mean()
    chroma_stdev = features_df_chromagram.stack().std()
    print(
        f"12 Chromagram features:       \
    min = {chroma_min:.3f}, \
    max = {chroma_max:.3f}, \
    mean = {chroma_mean:.3f}, \
    deviation = {chroma_stdev:.3f}"
    )

    # Check mel spectrogram feature values
    features_df_melspectrogram = df.loc[:, 12:139]
    mel_min = features_df_melspectrogram.min().min()
    mel_max = features_df_melspectrogram.max().max()
    # stack all features into a single series so we don't get a mean of means or stdev of stdevs
    mel_mean = features_df_melspectrogram.stack().mean()
    mel_stdev = features_df_melspectrogram.stack().std()
    print(
        f"\n128 Mel Spectrogram features: \
    min = {mel_min:.3f}, \
    max = {mel_max:.3f}, \
    mean = {mel_mean:.3f}, \
    deviation = {mel_stdev:.3f}"
    )

    # Check MFCC feature values
    features_df_mfcc = df.loc[:, 140:179]
    mfcc_min = features_df_mfcc.min().min()
    mfcc_max = features_df_mfcc.max().max()
    # stack all features into a single series so we don't get a mean of means or stdev of stdevs
    mfcc_mean = features_df_mfcc.stack().mean()
    mfcc_stdev = features_df_mfcc.stack().std()
    print(
        f"\n40 MFCC features:             \
    min = {mfcc_min:.3f},\
    max = {mfcc_max:.3f},\
    mean = {mfcc_mean:.3f},\
    deviation = {mfcc_stdev:.3f}"
    )


print_features(features_df)
# Out:
# 12 Chromagram features:           min = 0.310,     max = 0.874,     mean = 0.666,     deviation = 0.085
#
# 128 Mel Spectrogram features:     min = 0.000,     max = 149.208,     mean = 0.188,     deviation = 1.600
#
# 40 MFCC features:                 min = -873.242,    max = 115.126,    mean = -14.626,    deviation = 98.494

# %% [markdown]
# **There's an obvious imbalance in the variance our features; Our features indeed belong to very different distributions:** our MFC coefficients' deviation is greater than the other features by orders of magnitude. That does not mean MFC coefficients are the most important feature, but rather it is a property of the way they are computed. We will certainly need to scale this feature set.
#
# We have the choice of sklearn's StandardScaler and MinMaxScaler. Standard scaling subtracts the mean of each feature and divides it by the standard deviation of that feature, producing features with mean at zero and unit variance - that is, a variance and standard deviation of 1. Min-Max scaling transforms each feature to be within a bounded interval that we specify.
#
# In practice, **MinMax scaling is especially useful when we know our features should be in a bounded interval**, such as pixel values in [0,255], while **standard scaling is perhaps more practical for features with unknown distributions** because centering the features at zero-mean with a standard deviation of 1 means extreme values will have less of an impact on the model's learned weights, i.e. the model is less sensitive to outliers.
#
# We'll create MinMax scaled features as well so we can give them a try later on to confirm that standard scaling is better in the absence of knowledge on the appropriate distribution for a dataset's features.

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler

scaler = StandardScaler()
# keep our unscaled features just in case we need to process them alternatively
features_scaled = features
features_scaled = scaler.fit_transform(features_scaled)

scaler = MinMaxScaler()
# keep our unscaled features just in case we need to process them alternatively
features_minmax = features
features_minmax = scaler.fit_transform(features_minmax)

# %% [markdown]
# Make sure our features are properly scaled:

# %%
print("\033[1m" + "Standard Scaling:\n" + "\033[0m")
features_scaled_df = pd.DataFrame(features_scaled)
print_features(features_scaled_df)

print("\n\n\033[1m" + "MinMax Scaling:\n" + "\033[0m")
features_minmax_df = pd.DataFrame(features_minmax)
print_features(features_minmax_df)
# Out:
# Standard Scaling:
#
# 12 Chromagram features:           min = -3.957,     max = 2.645,     mean = -0.000,     deviation = 1.000
#
# 128 Mel Spectrogram features:     min = -0.475,     max = 36.480,     mean = -0.000,     deviation = 1.000
#
# 40 MFCC features:                 min = -4.209,    max = 6.240,    mean = 0.000,    deviation = 1.000
#
#
# MinMax Scaling:
#
# 12 Chromagram features:           min = 0.000,     max = 1.000,     mean = 0.611,     deviation = 0.181
#
# 128 Mel Spectrogram features:     min = 0.000,     max = 1.000,     mean = 0.015,     deviation = 0.061
#
# 40 MFCC features:                 min = 0.000,    max = 1.000,    mean = 0.406,    deviation = 0.166

# %% [markdown]
# Perfect. Zero mean and unit variance for standard scaling and in the range [0,1] for MinMax scaling - a default when we don't specify values. We can now move on to building predictive models for these features.
